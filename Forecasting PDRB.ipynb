# %% [markdown]
# # Pendahuluan
# Tabel yang dibutuhkan:
# 1. Tabel PDRB

# %% [markdown]
# ### Penjelasan
# browseURL("https://github.com/idabdulmaj/ForecastPDRB64/blob/Utama/README.md")
# ### Install Package Forecasting PDRB (HANYA UNTUK PERTAMA)
# install.packages("devtools")
#
# devtools::install_github("idabdulmaj/ForecastPDRB64")

# %% [markdown]
# # Persiapan - Mengatur Working Directory dan Library Loading

# %%
library(ForecastPDRB64)
cek.package.nya()
# Out:
# Seluruh package telah diinstall.
# ===== Loading package yang telah diinstall =====
# Warning message:
# "package 'openxlsx' was built under R version 4.4.2"
# Warning message:
# "package 'forecast' was built under R version 4.4.2"
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Loading required package: MASS
#
# Loading required package: lattice
#
# Loading required package: ggplot2
#
# Warning message:
# "package 'ggplot2' was built under R version 4.4.3"
#
# Loaded mixOmics 6.28.0
# Thank you for using mixOmics!
# Tutorials: http://mixomics.org
# Bookdown vignette: https://mixomicsteam.github.io/Bookdown
# Questions, issues: Follow the prompts at http://mixomics.org/contact-us
# Cite us:  citation('mixOmics')
#
#
# Warning message:
# "package 'tibble' was built under R version 4.4.2"
# ~~ Package ggcats
# Visit https://r-coder.com/ for R tutorials ~~
# Seluruh package telah di-Load.

# %% [markdown]
# # Data Frame Loading

# %%
pdrb_df <- read.xlsx("1. Data Input/pdrb.xlsx")
data.pdrb <- pdrb_df[, 3:ncol(pdrb_df)]
head(data.pdrb)
# Out:
#   Pertanian,.Kehutanan,.dan.Perikanan
# 1 5061923
# 2 5264377
# 3 5427419
# 4 5414053
# 5 5463379
# 6 5519474
#   Pertanian,.Peternakan,.Perburuan.dan.Jasa.Pertanian a..Tanaman.Pangan
# 1 2679265                                             281641.6
# 2 2860123                                             337228.3
# 3 2968735                                             293490.4
# 4 2943774                                             204101.4
# 5 3029560                                             323223.2
# 6 3074902                                             290412.8
#   b..Tanaman.Hortikultura.Semusim c..Perkebunan.Semusim
# 1  93578.43                       813.1914
# 2  89727.76                       788.4309
# 3  86896.94                       774.9625
# 4  86018.52                       762.1452
# 5 102938.85                       895.4760
# 6  99263.53                       890.1021
#   d..Tanaman.Hortikultura.Tahunan.dan.Lainnya e..Perkebunan.Tahunan
# 1 268287.2                                    1724687
# 2 234015.8                                    1883041
# 3 211665.9                                    2056856
# 4 213170.8                                    2117865
# 5 232459.6                                    2048247
# 6 225186.2                                    2138730
#   f..Peternakan g..Jasa.Pertanian.dan.Perburuan Kehutanan.dan.Penebangan.Kayu ⋯
# 1 275126.1      35131.59                        1309869                       ⋯
# 2 280125.3      35196.36                        1313616                       ⋯
# 3 283899.3      35152.24                        1323623                       ⋯
# 4 287081.7      34774.47                        1326448                       ⋯
# 5 283832.9      37963.48                        1305181                       ⋯
# 6 282551.5      37868.22                        1301607                       ⋯
#   Jasa.Keuangan.Lainnya Jasa.Penunjang.Keuangan Real.Estate Jasa.Perusahaan
# 1 239393.2              16.94446                694171.9    145311.8
# 2 243302.3              17.18775                700625.4    149928.1
# 3 247499.0              17.36353                715171.5    157520.1
# 4 249790.0              17.53427                727934.7    162351.4
# 5 253512.9              17.77842                733461.7    165283.8
# 6 256575.8              18.01299                745239.4    172720.5
#   Administrasi.Pemerintahan,.Pertahanan.dan.Jaminan.Sosial.Wajib
# 1 1424258
# 2 1496382
# 3 1614642
# 4 1633911
# 5 1528647
# 6 1604775
#   Jasa.Pendidikan Jasa.Kesehatan.dan.Kegiatan.Sosial Jasa.lainnya
# 1 546125.5        309281.6                           361639.0
# 2 620918.9        334221.7                           377506.9
# 3 698794.7        353717.6                           389428.7
# 4 715595.2        360473.5                           397358.1
# 5 653025.8        350846.8                           395992.2
# 6 746519.8        370592.1                           401982.3
#   PRODUK.DOMESTIK.REGIONAL.BRUTO PRODUK.DOMESTIK.REGIONAL.BRUTO.TANPA.MIGAS
# 1 94384716                       57773607
# 2 94974406                       58939725
# 3 95583067                       60263313
# 4 98350813                       63053632
# 5 98339373                       64184025
# 6 99852518                       66484084

# %% [markdown]
# # FORECASTING

# %%
suppressWarnings(forecast.pdrb.64(data.pdrb))
buka.hasil()
# Out:
# --------------------------------------------------------------------------------------
# Model dan Plot ARIMA disimpan pada folder 2. ARIMA Plot dan Model
# --------------------------------------------------------------------------------------
# Model dan Plot Exponential Smoothing disimpan pada 3. Exp Smoothing Plot dan Model
# --------------------------------------------------------------------------------------
# File Excel Forcasted Value dan Fitted Value telah disimpan di Folder 4. Output R
# --------------------------------------------------------------------------------------
# plot without title
